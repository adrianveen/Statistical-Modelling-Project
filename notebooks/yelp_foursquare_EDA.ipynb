# %%
# imports
import pandas as pd
import os # use this to access your environment variables
import requests # this will be used to call the APIs
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import json

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
#define function for getting POIs etc. from foursquare
def get_venues_fs(latitude, longitude, radius, api_key, categories):
    url_fs = "https://api.foursquare.com/v3/places/search"
    

    params = {
        "ll": f"{latitude},{longitude}",
        "radius": radius,
        "categories": categories,
        "fields": "fsq_id,name,geocodes,location,categories,distance,rating,price,closed_bucket"
    }

    headers = {
        "Accept": "application/json",
        "Authorization": api_key
    }


    # """
    # Get venues from foursquare with a specified place type and coordinates.
    # Args:
    #     latitude (float): latitude for query (must be combined with longitude)
    #     longitude (float): longitude for query (must be combined with latitude)
    #     api_key (str): foursquare API to use for query
    #     categories (str) : Foursquare-recognized place type. If not passed no place_type will be specified. 
    #     Separate ids with commas
    
    # Returns:
    #     response: response object from the requests library.
    # """
    response = requests.request("GET", url_fs, headers=headers, params=params)

    return response

# %% [markdown]
# Iterate through all locations

# %%
# load bike stations .csv
tor_csv = pd.read_csv('tor_stations.csv')
tor_csv.info()

tor_csv.sample(n=200).reset_index(drop=True).to_csv('tor_stations_sample.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 751 entries, 0 to 750
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   empty_slots  751 non-null    int64
#  1   free_bikes   751 non-null    int64
#  2   id           751 non-null    object
#  3   latitude     751 non-null    float64
#  4   longitude    751 non-null    float64
#  5   name         751 non-null    object
#  6   timestamp    751 non-null    object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 41.2+ KB

# %%
#assign api key variable
fs_key = os.getenv('FOURSQUARE_API_KEY')
radius = 1000
categories = '13003, 12080, 16032, 13065, 19042, 19043, 19046, 19054, 19067'

# %%
fs_key
# Out:
# 'fsq3E6A3NqmjGtMTfxyXK6KU0IRj74JX1NakuK7+E49mCcg='

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
#load sample of 200 stations
tor_csv_200 = pd.read_csv('tor_stations_sample.csv')
tor_csv_200
# Out:
#      empty_slots  free_bikes                                id   latitude  \
# 0              3          23  dcbcf9c681fbd3e77dfbea6df0e070bc  43.645857
# 1              0          18  d1de2ddc0ea8a90d00ff717ad60a2f23  43.638497
# 2              3          12  9fd381407b51a700753caec17607a127  43.647508
# 3              3          16  f42363acf4af847ca6fcdbe9b48c8290  43.637981
# 4             14           2  c4a01864ecb66e9b1ee3023d3205a281  43.680022
# ..           ...         ...                               ...        ...
# 195           13           0  f36d8ed5ff407fc4eab6c9cc344661f9  43.687323
# 196            8           6  719e676d739529c8d5da8bb89c5c8678  43.695019
# 197            0          23  d0a8478c786cb2480de4fcecda844781  43.643975
# 198           19           1  f0af815a9e6c12bd0382843e03fd322f  43.706347
# 199           11           0  0abdfc3177000757dcd71bd4c8b479ee  43.670000
#
#      longitude                                   name  \
# 0   -79.385365      Simcoe St / Wellington St W South
# 1   -79.391920  Lower Spadina Ave / Lake Shore Blvd W
# 2   -79.386044                  Simcoe St / King St W
# 3   -79.424146        Liberty St / Fraser Ave Green P
# 4   -79.340568    Langford Ave / Danforth Ave - SMART
# ..         ...                                    ...
# 195 -79.304848            Danforth Ave / Westlake Ave
# 196 -79.271807              Danforth Ave / Warden Ave
# 197 -79.419576             Queen St W / Ossington Ave
# 198 -79.401610     Eglinton Ave W / Henning Ave SMART
# 199 -79.420833              Yarmouth Rd / Christie St
#
#                             timestamp
# 0    2023-11-17 15:55:45.502000-05:00
# 1    2023-11-17 15:55:44.622000-05:00
# 2    2023-11-17 15:55:45.336000-05:00
# 3    2023-11-17 15:55:45.472000-05:00
# 4    2023-11-17 15:55:45.220000-05:00
# ..                                ...
# 195  2023-11-17 15:55:45.593000-05:00
# 196  2023-11-17 15:55:45.555000-05:00
# 197  2023-11-17 15:55:44.670000-05:00
# 198  2023-11-17 15:55:45.562000-05:00
# 199  2023-11-17 15:55:44.707000-05:00
#
# [200 rows x 7 columns]

# %%
#iterate through each row and retrieve latitude and longitude, passing them through get_venues_fs
pois = []

for index, row in tor_csv_200.iterrows():
    stations = get_venues_fs(tor_csv_200.at[index, 'latitude'], tor_csv_200.at[index, 'longitude'], radius=radius, api_key=fs_key, categories=categories)
    stations_json = stations.json()
    for item in stations_json['results']:
    # Extract the values for each desired key, with checks for existence of keys
        names = []
        [names.append(cat['name']) for cat in item['categories']]
        pois.append({
            'closest bike station id': tor_csv_200.loc[index, 'id'],
            'poi_id': item.get('fsq_id'),
            'poi_name': item.get('name'),
            'address': item['location']['formatted_address'] if item.get('location') else None,
            'distance': item.get('distance'),
            'longitude': item['geocodes']['main']['longitude'] if item.get('geocodes') and item['geocodes'].get('main') else None,
            'latitude': item['geocodes']['main']['latitude'] if item.get('geocodes') and item['geocodes'].get('main') else None,
            'categories': names,
            'rating': item.get('rating'),
            'price': item.get('price')
        })

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
fs_df = pd.DataFrame(pois)

fs_df
# Out:
#                closest bike station id                    poi_id  \
# 0     dcbcf9c681fbd3e77dfbea6df0e070bc  529612de11d2ab526191ccc9
# 1     dcbcf9c681fbd3e77dfbea6df0e070bc  5462ac56498e128ccafe8fea
# 2     dcbcf9c681fbd3e77dfbea6df0e070bc  5c08474447f876002c736b68
# 3     dcbcf9c681fbd3e77dfbea6df0e070bc  50322b6ae4b09116a296568c
# 4     dcbcf9c681fbd3e77dfbea6df0e070bc  5b6c842bc36588002c80a934
# ...                                ...                       ...
# 1986  0abdfc3177000757dcd71bd4c8b479ee  4af5a445f964a520b4fa21e3
# 1987  0abdfc3177000757dcd71bd4c8b479ee  54713d37498ec7371141032e
# 1988  0abdfc3177000757dcd71bd4c8b479ee  50456a23e4b0a30df06f1391
# 1989  0abdfc3177000757dcd71bd4c8b479ee  54400bee498e61defb21f0a5
# 1990  0abdfc3177000757dcd71bd4c8b479ee  4ada53e5f964a520592121e3
#
#                        poi_name  \
# 0                           Pai
# 1             Pizzeria Libretto
# 2           Wvrst Union Station
# 3                    Soho House
# 4                  Cafe Landwer
# ...                         ...
# 1986        Vermont Square Park
# 1987            Civil Liberties
# 1988  Tallboys Craft Beer House
# 1989        Schmaltz Appetizing
# 1990   Buk Chang Dong Soon Tofu
#
#                                                 address  distance  longitude  \
# 0     18 Duncan St (at Adelaide St W), Toronto ON M5...       345 -79.388636
# 1     155 University Ave (at Pearl St), Toronto ON M...       275 -79.384955
# 2                     65 Front St W, Toronto ON M5J 1E6       335 -79.381397
# 3     192 Adelaide St W (at Simcoe St.), Toronto ON ...       333 -79.386412
# 4     165 University Ave (Adelaide St W), Toronto ON...       321 -79.385137
# ...                                                 ...       ...        ...
# 1986  819 Palmerston Ave (Bathurst & Dupont area), T...       440 -79.415980
# 1987  878 Bloor St W (at Ossington Ave), Toronto ON ...       945 -79.425123
# 1988   838 Bloor St W (at Shaw St.), Toronto ON M6G 1M2       869 -79.423902
# 1989                  414 Dupont St, Toronto ON M5R 1V9       844 -79.411685
# 1990  691 Bloor St W (at Clinton St.), Toronto ON M6...       747 -79.416945
#
#        latitude                categories  rating  price
# 0     43.647796         [Thai Restaurant]     9.3    2.0
# 1     43.648456                [Pizzeria]     8.7    2.0
# 2     43.644898                [Beer Bar]     8.9    NaN
# 3     43.648800  [Speakeasy, Social Club]     8.9    2.0
# 4     43.648724        [Café, Restaurant]     8.8    1.0
# ...         ...                       ...     ...    ...
# 1986  43.670004              [Playground]     7.9    NaN
# 1987  43.662264            [Cocktail Bar]     8.8    3.0
# 1988  43.662521         [Pub, Restaurant]     8.6    2.0
# 1989  43.673854                    [Deli]     8.5    1.0
# 1990  43.663758       [Korean Restaurant]     8.3    1.0
#
# [1991 rows x 10 columns]

# %%
#save df to csv
fs_df.to_csv('fs_df.csv', index=False)

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
#yelp endpoint
yelp_url = 'https://api.yelp.com/v3'

#business search endpoint
ylp_endpoint = '/businesses/search'

#yelp api key
yelp_key = os.getenv('YELP_API_KEY')

# %%
#create function for calling yelp api
def get_venues_yelp(latitude, longitude,  api_key, radius=1000, categories=None, endpoint=None):
    # Get venues from foursquare with a specified place type and coordinates.
    # Args:
    #     latitude (float): latitude for query
    #     longitude (float): longitude for query
    #     api_key (str): yelp API to use for query
    #     categories (str) : yelp-recognized place type. If not passed no place_type will be specified. 
    # Returns:
    #     response: response object from the requests library.
    
    if endpoint is not None:
        url = 'https://api.yelp.com/v3' + endpoint
    else:
        url = 'https://api.yelp.com/v3/'

    params = {
        "latitude": latitude,
        "longitude": longitude,
        "radius": radius,
        "categories": categories,
        "limit": 10
    }

    headers = {
        "Accept": "application/json",
        'Authorization': 'Bearer %s' % api_key
    }

    response = requests.request("GET", url, headers=headers, params=params)

    return response

# %%
#testing calls with single location
#43.654905	-79.398448 - Spadina and Baldwin
testlat = 43.654905
testlon = -79.398448
rad = 1000
test1 = get_venues_fs(latitude=testlat, longitude=testlon, radius=rad, api_key=fs_key, categories='13003')

# %%
test1.json()
# Out:
# {'results': [{'fsq_id': '589bc46a739d8546efb5f2fd',
#    'categories': [{'id': 13025,
#      'name': 'Wine Bar',
#      'short_name': 'Wine Bar',
#      'plural_name': 'Wine Bars',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 287,
#    'geocodes': {'drop_off': {'latitude': 43.653759, 'longitude': -79.401708},
#     'main': {'latitude': 43.653818, 'longitude': -79.401564},
#     'roof': {'latitude': 43.653818, 'longitude': -79.401564}},
#    'location': {'address': '199 Augusta Ave',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '199 Augusta Ave, Toronto ON M5T 2L4',
#     'locality': 'Toronto',
#     'postcode': 'M5T 2L4',
#     'region': 'ON'},
#    'name': 'Grey Gardens',
#    'price': 2,
#    'rating': 8.6},
#   {'fsq_id': '5061dbab498ee603149683e5',
#    'categories': [{'id': 13003,
#      'name': 'Bar',
#      'short_name': 'Bar',
#      'plural_name': 'Bars',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 608,
#    'geocodes': {'drop_off': {'latitude': 43.656889, 'longitude': -79.405555},
#     'main': {'latitude': 43.657062, 'longitude': -79.405588},
#     'roof': {'latitude': 43.657062, 'longitude': -79.405588}},
#    'location': {'address': '388 College St',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '388 College St, Toronto ON M5T 1S7',
#     'locality': 'Toronto',
#     'postcode': 'M5T 1S7',
#     'region': 'ON'},
#    'name': 'Voodoo Child',
#    'price': 1,
#    'rating': 8.9},
#   {'fsq_id': '5b233c5595d986002c9e8788',
#    'categories': [{'id': 13003,
#      'name': 'Bar',
#      'short_name': 'Bar',
#      'plural_name': 'Bars',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13139,
#      'name': 'Eastern European Restaurant',
#      'short_name': 'Eastern European',
#      'plural_name': 'Eastern European Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 758,
#    'geocodes': {'main': {'latitude': 43.648297, 'longitude': -79.399514},
#     'roof': {'latitude': 43.648297, 'longitude': -79.399514}},
#    'location': {'address': '458 Queen St W',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '458 Queen St W, Toronto ON M5V 2A8',
#     'locality': 'Toronto',
#     'postcode': 'M5V 2A8',
#     'region': 'ON'},
#    'name': 'Drom Taberna',
#    'price': 2,
#    'rating': 8.9},
#   {'fsq_id': '4ad7bb35f964a520340e21e3',
#    'categories': [{'id': 13010,
#      'name': 'Dive Bar',
#      'short_name': 'Dive Bar',
#      'plural_name': 'Dive Bars',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/divebar_',
#       'suffix': '.png'}}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 340,
#    'geocodes': {'drop_off': {'latitude': 43.655135, 'longitude': -79.402758},
#     'main': {'latitude': 43.655023, 'longitude': -79.402738},
#     'roof': {'latitude': 43.655023, 'longitude': -79.402738}},
#    'location': {'address': '69 Nassau St',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '69 Nassau St, Toronto ON M5T 1M6',
#     'locality': 'Toronto',
#     'postcode': 'M5T 1M6',
#     'region': 'ON'},
#    'name': "Ronnie's Local 069",
#    'price': 2,
#    'rating': 7.9},
#   {'fsq_id': '55175269498ef06e96eeeb98',
#    'categories': [{'id': 10000,
#      'name': 'Arts and Entertainment',
#      'short_name': 'Arts & Entertainment',
#      'plural_name': 'Arts and Entertainment',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#       'suffix': '.png'}},
#     {'id': 13003,
#      'name': 'Bar',
#      'short_name': 'Bar',
#      'plural_name': 'Bars',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 394,
#    'geocodes': {'main': {'latitude': 43.656656, 'longitude': -79.402671},
#     'roof': {'latitude': 43.656656, 'longitude': -79.402671}},
#    'location': {'address': '303 Augusta Ave',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '303 Augusta Ave, Toronto ON M5T 2M2',
#     'locality': 'Toronto',
#     'postcode': 'M5T 2M2',
#     'region': 'ON'},
#    'name': 'Trinity Common',
#    'price': 2,
#    'rating': 8.0},
#   {'fsq_id': '4ae2620df964a520da8d21e3',
#    'categories': [{'id': 13003,
#      'name': 'Bar',
#      'short_name': 'Bar',
#      'plural_name': 'Bars',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}}],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 281,
#    'geocodes': {'drop_off': {'latitude': 43.654254, 'longitude': -79.401911},
#     'main': {'latitude': 43.654307, 'longitude': -79.401782},
#     'roof': {'latitude': 43.654307, 'longitude': -79.401782}},
#    'location': {'address': '223 Augusta Ave',
#     'country': 'CA',
#     'formatted_address': '223 Augusta Ave, Toronto ON M5T 2L4',
#     'locality': 'Toronto',
#     'postcode': 'M5T 2L4',
#     'region': 'ON'},
#    'name': 'The Embassy Bar',
#    'price': 2,
#    'rating': 7.8},
#   {'fsq_id': '4ad4c05df964a5204cf620e3',
#    'categories': [{'id': 13016,
#      'name': 'Lounge',
#      'short_name': 'Lounge',
#      'plural_name': 'Lounges',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#       'suffix': '.png'}},
#     {'id': 13049,
#      'name': 'Diner',
#      'short_name': 'Diner',
#      'plural_name': 'Diners',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#       'suffix': '.png'}},
#     {'id': 13307,
#      'name': 'Tex-Mex Restaurant',
#      'short_name': 'Tex-Mex',
#      'plural_name': 'Tex-Mex Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#       'suffix': '.png'}}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 738,
#    'geocodes': {'main': {'latitude': 43.656372, 'longitude': -79.407348},
#     'roof': {'latitude': 43.656372, 'longitude': -79.407348}},
#    'location': {'address': '431 College St',
#     'country': 'CA',
#     'cross_street': 'at Bathurst St',
#     'formatted_address': '431 College St (at Bathurst St), Toronto ON M5T 1T1',
#     'locality': 'Toronto',
#     'postcode': 'M5T 1T1',
#     'region': 'ON'},
#    'name': "Sneaky Dee's",
#    'price': 1,
#    'rating': 8.6},
#   {'fsq_id': '5612ea8b498e102e764fc304',
#    'categories': [{'id': 13006,
#      'name': 'Beer Bar',
#      'short_name': 'Beer Bar',
#      'plural_name': 'Beer Bars',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13057,
#      'name': 'Gastropub',
#      'short_name': 'Gastropub',
#      'plural_name': 'Gastropubs',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#       'suffix': '.png'}},
#     {'id': 13152,
#      'name': 'Brasserie',
#      'short_name': 'Brasserie',
#      'plural_name': 'Brasseries',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#       'suffix': '.png'}}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 762,
#    'geocodes': {'main': {'latitude': 43.649093, 'longitude': -79.39319},
#     'roof': {'latitude': 43.649093, 'longitude': -79.39319}},
#    'location': {'address': '137 Peter St',
#     'country': 'CA',
#     'cross_street': 'Peter & Richmond',
#     'formatted_address': '137 Peter St (Peter & Richmond), Toronto ON M5V 2H3',
#     'locality': 'Toronto',
#     'postcode': 'M5V 2H3',
#     'region': 'ON'},
#    'name': 'Bar Hop Brewco',
#    'rating': 8.6},
#   {'fsq_id': '4ae513ebf964a52041a021e3',
#    'categories': [{'id': 13016,
#      'name': 'Lounge',
#      'short_name': 'Lounge',
#      'plural_name': 'Lounges',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#       'suffix': '.png'}},
#     {'id': 13018,
#      'name': 'Pub',
#      'short_name': 'Pub',
#      'plural_name': 'Pubs',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 622,
#    'geocodes': {'drop_off': {'latitude': 43.656871, 'longitude': -79.405645},
#     'main': {'latitude': 43.657055, 'longitude': -79.405681},
#     'roof': {'latitude': 43.657055, 'longitude': -79.405681}},
#    'location': {'address': '394 College St',
#     'country': 'CA',
#     'cross_street': 'btw Borden & Croft',
#     'formatted_address': '394 College St (btw Borden & Croft), Toronto ON M5T 1S7',
#     'locality': 'Toronto',
#     'postcode': 'M5T 1S7',
#     'region': 'ON'},
#    'name': 'Cloak & Dagger Irish Pub',
#    'price': 1,
#    'rating': 8.3},
#   {'fsq_id': '5b3fea7b66f3cd002c01d450',
#    'categories': [{'id': 13009,
#      'name': 'Cocktail Bar',
#      'short_name': 'Cocktail',
#      'plural_name': 'Cocktail Bars',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#       'suffix': '.png'}}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 238,
#    'geocodes': {'drop_off': {'latitude': 43.653405, 'longitude': -79.395836},
#     'main': {'latitude': 43.653503, 'longitude': -79.395856},
#     'roof': {'latitude': 43.653503, 'longitude': -79.395856}},
#    'location': {'address': '460 Dundas St W',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '460 Dundas St W, Toronto ON M5T 1G9',
#     'locality': 'Toronto',
#     'postcode': 'M5T 1G9',
#     'region': 'ON'},
#    'name': 'Big Trouble',
#    'price': 3,
#    'rating': 7.6}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 43.654905,
#      'longitude': -79.398448},
#     'radius': 1000}}}}

# %%
ylptestjson = test1.json()

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
rad = 1000
categories = 'bars, restaurants, libraries, parks, cafes, metrostations, busstations'

# %%
#parse through sample of 200 stations
pois_ylp = []

for index, row in tor_csv_200.iterrows():
    stations_ylp = get_venues_yelp(tor_csv_200.at[index, 'latitude'], tor_csv_200.at[index, 'longitude'], radius=rad, api_key=yelp_key, categories=categories, endpoint=ylp_endpoint)
    stations_ylp_json = stations_ylp.json()
    for item in stations_ylp_json['businesses']:
    #extract values for each desired key 
        cat_names = []
        [cat_names.append(cat['title']) for cat in item['categories']]
        pois_ylp.append({
            'closest bike station id': tor_csv_200.loc[index, 'id'],
            'poi_id': item.get('id'),
            'name': item.get('name'),
            'address': item.get('location').get('display_address')[0] if item.get('location') else None,
            'distance': item.get('distance'),
            'longitude': item.get('coordinates').get('longitude') if item.get('coordinates') else None, 
            'latitude': item.get('coordinates').get('latitude') if item.get('coordinates') else None,
            'categories': cat_names,
            'rating': item.get('rating'),
            'price': item.get('price')
        })

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
ylp_df = pd.DataFrame(pois_ylp)
ylp_df
# Out:
#                closest bike station id                  poi_id  \
# 0     dcbcf9c681fbd3e77dfbea6df0e070bc  r_BrIgzYcwo1NAuG9dLbpg
# 1     dcbcf9c681fbd3e77dfbea6df0e070bc  Yl2TN9c23ZGLUBSD9ks5Uw
# 2     dcbcf9c681fbd3e77dfbea6df0e070bc  jGO4T6rGX3EIOwOtg4bZqg
# 3     dcbcf9c681fbd3e77dfbea6df0e070bc  ocLnCE2E29j-CoBQj1yaSA
# 4     dcbcf9c681fbd3e77dfbea6df0e070bc  JMiaNitMzMbJm6Kh0RbT5A
# ...                                ...                     ...
# 1980  0abdfc3177000757dcd71bd4c8b479ee  -ltD-dHqdZ5-wjAMKYa6Ng
# 1981  0abdfc3177000757dcd71bd4c8b479ee  QA30Lo1NlV8SjnkmEkd1-A
# 1982  0abdfc3177000757dcd71bd4c8b479ee  oZP0Ynj-yHUxJUmY7-HaUA
# 1983  0abdfc3177000757dcd71bd4c8b479ee  nHFJtud7jWZhM9dHQ1eIRA
# 1984  0abdfc3177000757dcd71bd4c8b479ee  ohEGwJtSqrVd2SD-FKKrUQ
#
#                                       name                  address  \
# 0                Pai Northern Thai Kitchen         18 Duncan Street
# 1                                   Byblos         11 Duncan Street
# 2                       Lobster Burger Bar        214 King Street W
# 3     Cafe Landwer - Adelaide & University    165 University Avenue
# 4                                    Canoe  66 Wellington Street  W
# ...                                    ...                      ...
# 1980                      La Bella Managua       872 Bloor Street W
# 1981      Daldongnae Korean BBQ - Christie         658 Bloor Street
# 1982                   Rustle & Still Café       605 Bloor Street W
# 1983              Buk Chang Dong Soon Tofu       691 Bloor Street W
# 1984                       Napoli Centrale      964 Bathurst Street
#
#         distance  longitude   latitude  \
# 0     348.204192 -79.388720  43.647840
# 1     290.701203 -79.388123  43.647546
# 2     209.383312 -79.386768  43.647443
# 3     325.377024 -79.384910  43.648750
# 4     285.381498 -79.382159  43.646954
# ...          ...        ...        ...
# 1980  919.489403 -79.424950  43.662320
# 1981  758.561743 -79.415660  43.664340
# 1982  868.963300 -79.413040  43.664570
# 1983  784.093681 -79.416930  43.663630
# 1984  634.357953 -79.412975  43.669518
#
#                                       categories  rating price
# 0                                         [Thai]     4.5    $$
# 1                [Mediterranean, Middle Eastern]     4.5  $$$$
# 2                       [Bars, Seafood, Burgers]     4.0    $$
# 3     [Cafes, Breakfast & Brunch, Mediterranean]     4.0    $$
# 4                               [Canadian (New)]     4.0  $$$$
# ...                                          ...     ...   ...
# 1980                [Latin American, Nicaraguan]     4.5    $$
# 1981                          [Korean, Barbeque]     4.5   $$$
# 1982                  [Coffee & Tea, Vietnamese]     4.5     $
# 1983                                    [Korean]     4.0    $$
# 1984                            [Italian, Pizza]     4.5    $$
#
# [1985 rows x 10 columns]

# %%
ylp_df.to_csv('ylp_df.csv', index=False)

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# Although Foursquare may have more data per business for a similar query, much of it seems redundant or unnecessary, such as the longitude and latitude listed multiple times.
#
# Yelp has the rating and a price rating for each establishment which is only two more data points but offers a large benefit over using foursquare. Foursquare also has this information but is behind a paywall, making it less accessible.
#
# After some manual inspectiong, however, it appears that yelp has POIs that have since permanently closed but are still returned in the request. There does not appear to be a parameter that can be passed to ensure that the business are still operating at the same address.
#
# Foursquare offers some insight into whether or not the establishment is still open with their 'closed_bucket' attribute. With the shortcomings of yelp with regards to businesses still in operation, Foursquare is the more complete data source.

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %% [markdown]
# As Yelp's rating system is on a 5 point scale with 0.5 resolution, and some POIs with 5 start ratings have been confirmed to be permanently closed, the Foursquare data will be used instead for the top 10 restaurants.

# %%
#Top 10 restaurants by rating
top_ten = fs_df.drop_duplicates(subset=['poi_name']).sort_values(by='rating', ascending=False)

# %%
top_ten[~top_ten['poi_name'].str.contains('park', case=False)].head(10)
# Out:
#               closest bike station id                    poi_id  \
# 416  71debce521f35fd4e280e8ee1e2dd8cc  550dfcb6498e446e1eff9031
# 83   5539f3700e4ce9e5701353a667924538  4f7891c7e4b0b9643b73e08d
# 0    dcbcf9c681fbd3e77dfbea6df0e070bc  529612de11d2ab526191ccc9
# 256  7a666ee6c60a7f8ffec9334924d36c6a  5321f4d9e4b07946702e6e08
# 6    dcbcf9c681fbd3e77dfbea6df0e070bc  4ad4c05ef964a520cbf620e3
# 87   5539f3700e4ce9e5701353a667924538  4af369d0f964a52060ed21e3
# 327  8db545a0135f7b92022fbdbbc75af6c4  527d450111d25050de4ea0d8
# 407  cc1432c52b1e87a738180d369ed1136b  4ad4c062f964a520fbf720e3
# 50   beb87ea54499f95a614653924c99b9c4  514a4961e4b004a36b8d9ea0
# 405  cc1432c52b1e87a738180d369ed1136b  4fff1f96e4b042ae8acddca5
#
#                                 poi_name  \
# 416                       Northern Belle
# 83                     Bellwoods Brewery
# 0                                    Pai
# 256                               Byblos
# 6                  Steam Whistle Brewing
# 87                                Foxley
# 327                                 Rasa
# 407  St. Lawrence Market Outdoor Vendors
# 50                            Bar Isabel
# 405                    Fahrenheit Coffee
#
#                                                address  distance  longitude  \
# 416  913 Dundas St W (at Bellwoods Ave), Toronto ON...       627 -79.412661
# 83   124 Ossington Ave (at Argyle St), Toronto ON M...       162 -79.420177
# 0    18 Duncan St (at Adelaide St W), Toronto ON M5...       345 -79.388636
# 256     11 Duncan St (at Pearl St), Toronto ON M5V 3M2       690 -79.388264
# 6    255 Bremner Blvd (btwn Rees St. & Simcoe St.),...       476 -79.385267
# 87      207 Ossington Ave (Dundas), Toronto ON M6J 2Z8       339 -79.420333
# 327                  196 Robert St, Toronto ON M5S 2K7       754 -79.404126
# 407  93 Front St E (at Lower Jarvis St), Toronto ON...       736 -79.371614
# 50                  797 College St, Toronto ON M6G 1C7       414 -79.420682
# 405  120 Lombard St (at Jarvis St), Toronto ON M5C 3H5       628 -79.372916
#
#       latitude                                         categories  rating  \
# 416  43.650838                   [Cocktail Bar, Café, Restaurant]     9.4
# 83   43.647131                         [Bar, Brewery, Restaurant]     9.3
# 0    43.647796                                  [Thai Restaurant]     9.3
# 256  43.647450                         [Mediterranean Restaurant]     9.3
# 6    43.641025                              [Brewery, Restaurant]     9.2
# 87   43.648691      [Bistro, Chinese Restaurant, Thai Restaurant]     9.2
# 327  43.662838                                       [Restaurant]     9.2
# 407  43.648637        [Restaurant, Farmers Market, Grocery Store]     9.2
# 50   43.654672  [Cocktail Bar, American Restaurant, Tapas Rest...     9.1
# 405  43.652416                    [Café, Coffee Shop, Restaurant]     9.1
#
#      price
# 416    3.0
# 83     3.0
# 0      2.0
# 256    2.0
# 6      1.0
# 87     2.0
# 327    NaN
# 407    1.0
# 50     3.0
# 405    2.0
